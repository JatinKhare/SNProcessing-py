# %% [markdown]
# <a href="https://colab.research.google.com/github/JatinKhare/SNProcessing-py/blob/master/JKCE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

import os

os.chdir('/content/drive/My Drive/GoogleColab/DRPKSS')
os.listdir()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ['1550nm0251.CSV',
#  '1550nm0252.CSV',
#  '20190312_143147.jpg',
#  '20190312_143149.jpg',
#  '20190312_143309.jpg',
#  '20190312_143310.jpg']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
X = pd.read_csv('1550nm0251.CSV')

print(X)
# Out:
#                  Label                Unnamed: 1
# 0            Date/Time  Tue Mar 12 17:39:55 2019
# 1           Wavelength                 SM 1550nm
# 2       Distance Range                      50km
# 3          Pulse Width                       3ns
# 4          Attenuation                    0.00dB
# 5            Avg Times                      2^20
# 6                  IOR                   1.46000
# 7            Data Size                     12500
# 8      Sample Interval                       4 m
# 9                 [km]                      [dB]
# 10            -0.09856                    23.201
# 11            -0.09446                    15.480
# 12            -0.09035                    15.480
# 13            -0.08624                    15.529
# 14            -0.08213                    15.529
# 15            -0.07803                    15.536
# 16            -0.07392                    15.530
# 17            -0.06981                    15.530
# 18            -0.06571                    15.530
# 19            -0.06160                    15.527
# 20            -0.05749                    15.527
# 21            -0.05339                    15.527
# 22            -0.04928                    15.543
# 23            -0.04517                    15.544
# 24            -0.04107                    15.544
# 25            -0.03696                    15.544
# 26            -0.03285                    15.549
# 27            -0.02875                    15.549
# 28            -0.02464                    15.521
# 29            -0.02053                    15.500
# ...                ...                       ...
# 12480         51.11256                     7.398
# 12481         51.11667                     7.398
# 12482         51.12077                     7.398
# 12483         51.12488                     7.369
# 12484         51.12899                     7.232
# 12485         51.13309                     7.232
# 12486         51.13720                     7.128
# 12487         51.14131                     7.128
# 12488         51.14541                     7.130
# 12489         51.14952                     7.150
# 12490         51.15363                     7.150
# 12491         51.15773                     7.216
# 12492         51.16184                     7.142
# 12493         51.16595                     7.142
# 12494         51.17006                     7.142
# 12495         51.17416                     7.259
# 12496         51.17827                     7.314
# 12497         51.18238                     7.460
# 12498         51.18648                     7.460
# 12499         51.19059                     7.318
# 12500         51.19470                     7.057
# 12501         51.19880                     7.057
# 12502         51.20291                     7.057
# 12503         51.20702                     6.869
# 12504         51.21112                     6.529
# 12505         51.21523                     6.178
# 12506         51.21934                     6.122
# 12507         51.22344                     5.600
# 12508         51.22755                     5.339
# 12509         51.23166                     0.000
#
# [12510 rows x 2 columns]

# %%
x = X.loc[10:12509, 'Label':'Unnamed: 1']
print(x)
# Out:
#           Label Unnamed: 1
# 10     -0.09856     23.201
# 11     -0.09446     15.480
# 12     -0.09035     15.480
# 13     -0.08624     15.529
# 14     -0.08213     15.529
# 15     -0.07803     15.536
# 16     -0.07392     15.530
# 17     -0.06981     15.530
# 18     -0.06571     15.530
# 19     -0.06160     15.527
# 20     -0.05749     15.527
# 21     -0.05339     15.527
# 22     -0.04928     15.543
# 23     -0.04517     15.544
# 24     -0.04107     15.544
# 25     -0.03696     15.544
# 26     -0.03285     15.549
# 27     -0.02875     15.549
# 28     -0.02464     15.521
# 29     -0.02053     15.500
# 30     -0.01643     15.500
# 31     -0.01232     15.522
# 32     -0.00821     15.532
# 33     -0.00411     15.571
# 34      0.00000     15.573
# 35      0.00411     32.686
# 36      0.00821     27.309
# 37      0.01232     23.654
# 38      0.01643     21.680
# 39      0.02053     19.607
# ...         ...        ...
# 12480  51.11256      7.398
# 12481  51.11667      7.398
# 12482  51.12077      7.398
# 12483  51.12488      7.369
# 12484  51.12899      7.232
# 12485  51.13309      7.232
# 12486  51.13720      7.128
# 12487  51.14131      7.128
# 12488  51.14541      7.130
# 12489  51.14952      7.150
# 12490  51.15363      7.150
# 12491  51.15773      7.216
# 12492  51.16184      7.142
# 12493  51.16595      7.142
# 12494  51.17006      7.142
# 12495  51.17416      7.259
# 12496  51.17827      7.314
# 12497  51.18238      7.460
# 12498  51.18648      7.460
# 12499  51.19059      7.318
# 12500  51.19470      7.057
# 12501  51.19880      7.057
# 12502  51.20291      7.057
# 12503  51.20702      6.869
# 12504  51.21112      6.529
# 12505  51.21523      6.178
# 12506  51.21934      6.122
# 12507  51.22344      5.600
# 12508  51.22755      5.339
# 12509  51.23166      0.000
#
# [12500 rows x 2 columns]

# %%
x_label = x['Label'].values
print(x_label)
x_dB = x['Unnamed: 1'].values
print(x_dB)
print(x_label.shape, x_dB.shape)
# Out:
# ['-0.09856' '-0.09446' '-0.09035' ... '51.22344' '51.22755' '51.23166']
# ['23.201' '15.480' '15.480' ... '5.600' '5.339' '0.000']
# (12500,) (12500,)

# %%
x_label = [float(i) for i in x_label]
x_label = np.array(x_label)
x_label.reshape(-1,1)

x_dB = [float(i) for i in x_dB]
x_dB = np.array(x_dB)
x_dB.reshape(-1,1)

print(x_label.shape, x_dB.shape)
# Out:
# (12500,) (12500,)

# %%
plt.plot(x_label, x_dB)
plt.show()

# %%
Q = pd.read_csv('1550nm0252.CSV')
print(Q)
# Out:
#                  Label                Unnamed: 1
# 0            Date/Time  Tue Mar 12 17:42:00 2019
# 1           Wavelength                 SM 1550nm
# 2       Distance Range                      50km
# 3          Pulse Width                       3ns
# 4          Attenuation                    0.00dB
# 5            Avg Times                      2^10
# 6                  IOR                   1.46000
# 7            Data Size                     12500
# 8      Sample Interval                       4 m
# 9                 [km]                      [dB]
# 10            -0.09856                    23.124
# 11            -0.09446                    15.389
# 12            -0.09035                    14.250
# 13            -0.08624                    14.250
# 14            -0.08213                    14.483
# 15            -0.07803                    14.505
# 16            -0.07392                    14.505
# 17            -0.06981                    14.505
# 18            -0.06571                    14.505
# 19            -0.06160                    14.505
# 20            -0.05749                    14.558
# 21            -0.05339                    14.558
# 22            -0.04928                    14.558
# 23            -0.04517                    14.662
# 24            -0.04107                    14.828
# 25            -0.03696                    14.828
# 26            -0.03285                    14.652
# 27            -0.02875                    14.652
# 28            -0.02464                    14.071
# 29            -0.02053                    15.381
# ...                ...                       ...
# 12480         51.11256                    11.074
# 12481         51.11667                    10.851
# 12482         51.12077                    11.127
# 12483         51.12488                    11.074
# 12484         51.12899                    11.074
# 12485         51.13309                    10.966
# 12486         51.13720                    10.851
# 12487         51.14131                    10.731
# 12488         51.14541                    10.246
# 12489         51.14952                     9.163
# 12490         51.15363                     9.163
# 12491         51.15773                     9.287
# 12492         51.16184                     9.722
# 12493         51.16595                     9.722
# 12494         51.17006                     9.404
# 12495         51.17416                     9.404
# 12496         51.17827                     9.404
# 12497         51.18238                     0.000
# 12498         51.18648                     0.000
# 12499         51.19059                     0.000
# 12500         51.19470                     0.000
# 12501         51.19880                     0.000
# 12502         51.20291                     0.000
# 12503         51.20702                     0.000
# 12504         51.21112                     0.000
# 12505         51.21523                     0.000
# 12506         51.21934                     0.000
# 12507         51.22344                     0.000
# 12508         51.22755                     0.000
# 12509         51.23166                     0.000
#
# [12510 rows x 2 columns]

# %%
q = Q.loc[10:12509, 'Label':'Unnamed: 1']
print(q)
# Out:
#           Label Unnamed: 1
# 10     -0.09856     23.124
# 11     -0.09446     15.389
# 12     -0.09035     14.250
# 13     -0.08624     14.250
# 14     -0.08213     14.483
# 15     -0.07803     14.505
# 16     -0.07392     14.505
# 17     -0.06981     14.505
# 18     -0.06571     14.505
# 19     -0.06160     14.505
# 20     -0.05749     14.558
# 21     -0.05339     14.558
# 22     -0.04928     14.558
# 23     -0.04517     14.662
# 24     -0.04107     14.828
# 25     -0.03696     14.828
# 26     -0.03285     14.652
# 27     -0.02875     14.652
# 28     -0.02464     14.071
# 29     -0.02053     15.381
# 30     -0.01643     15.381
# 31     -0.01232     15.396
# 32     -0.00821     15.396
# 33     -0.00411     15.439
# 34      0.00000     15.439
# 35      0.00411     32.692
# 36      0.00821     27.315
# 37      0.01232     23.685
# 38      0.01643     21.601
# 39      0.02053     19.718
# ...         ...        ...
# 12480  51.11256     11.074
# 12481  51.11667     10.851
# 12482  51.12077     11.127
# 12483  51.12488     11.074
# 12484  51.12899     11.074
# 12485  51.13309     10.966
# 12486  51.13720     10.851
# 12487  51.14131     10.731
# 12488  51.14541     10.246
# 12489  51.14952      9.163
# 12490  51.15363      9.163
# 12491  51.15773      9.287
# 12492  51.16184      9.722
# 12493  51.16595      9.722
# 12494  51.17006      9.404
# 12495  51.17416      9.404
# 12496  51.17827      9.404
# 12497  51.18238      0.000
# 12498  51.18648      0.000
# 12499  51.19059      0.000
# 12500  51.19470      0.000
# 12501  51.19880      0.000
# 12502  51.20291      0.000
# 12503  51.20702      0.000
# 12504  51.21112      0.000
# 12505  51.21523      0.000
# 12506  51.21934      0.000
# 12507  51.22344      0.000
# 12508  51.22755      0.000
# 12509  51.23166      0.000
#
# [12500 rows x 2 columns]

# %%
q_label = q['Label'].values
print(q_label)
q_dB = q['Unnamed: 1'].values
print(q_dB)
print(q_label.shape, q_dB.shape)
# Out:
# ['-0.09856' '-0.09446' '-0.09035' ... '51.22344' '51.22755' '51.23166']
# ['23.124' '15.389' '14.250' ... '0.000' '0.000' '0.000']
# (12500,) (12500,)

# %%
q_label = [float(i) for i in q_label]
q_label = np.array(results)
q_label.reshape(-1,1)

q_dB = [float(i) for i in q_dB]
q_dB = np.array(q_dB)
q_dB.reshape(-1,1)
print(q_label.shape, q_dB.shape)
# Out:
# (12500,) (12500,)

# %%
plt.plot(q_label, q_dB)
plt.show()

# %%
plt.specgram(x_dB,Fs = 100)
plt.xlabel('X_Time')
plt.ylabel('X_Frequency')
plt.show()


plt.specgram(q_dB,Fs = 100)
plt.xlabel('Q_Time')
plt.ylabel('Q_Frequency')
plt.show()
